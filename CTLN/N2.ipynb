# %%
import numpy as np
from scipy import *
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from xppcall import xpprun
import networkx as nx
import conley_functions as cf
import subprocess
# import nolds
# import scipy.optimize

# %%
npa, vn = xpprun('ctln2.ode',inits={'x1':.33,'x2':.331}, parameters={'total':10}, clean_after=True)
plt.plot(npa[:,1], npa[:,2])

# %%
plt.plot(npa[:,1])
plt.plot(npa[:,2])

# %%
x=npa[-1,1:]
x
# Out:
# array([0.00252222, 0.97129285])

# %%
-2*x[1]+1-x[0]
# Out:
# -1.9999999933961732e-08
